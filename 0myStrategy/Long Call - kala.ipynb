# %%
from tseopt import make_a_mercantile_data_object

md = make_a_mercantile_data_object()
md.update_data(timeout=20)
print(md.sandoq)
print(md.future_date_time)
print(md.markets_info)
# Out:
# []
# None
# [{'ContractCode': 'DGME05C23', 'CallContractID': 1001966, 'CallContractCode': 'DGME05C23', 'CallContractDescription': 'قرارداد اختیار معامله خرید واحدهای سرمایه گذاری صندوق طلای درخشان آبان سررسید مهر ماه 1405 با قیمت اعمال 23،000 ریال', 'CallLastTradingPersianDate': '1405/07/18', 'CallContractSize': 10.0, 'CallContractSizeUnitFaDesc': 'واحد', 'CallContractCurrencyFaDesc': 'ریال', 'CallContractCurrencyEnDesc': 'Rials', 'CallLastSettlementPrice': 12333.0, 'CallLastSettlementPricePersianDate': '1405/05/20', 'CallBidTotalVolume': None, 'CallBidVolume1': None, 'CallBidPrice1': None, 'CallBidVolume2': None, 'CallBidPrice2': None, 'CallBidVolume3': None, 'CallBidPrice3': None, 'CallBidVolume4': 0, 'CallBidPrice4': 0.0, 'CallBidVolume5': 0, 'CallBidPrice5': 0.0, 'CallAskTotalVolume': None, 'CallAskVolume1': None, 'CallAskPrice1': None, 'CallAskVolume2': None, 'CallAskPrice2': None, 'CallAskVolume3': None, 'CallAskPrice3': None, 'CallAskVolume4': 0, 'CallAskPrice4': 0.0, 'CallAskVolume5': 0, 'CallAskPrice5': 0.0, 'CallOrdersDateTime': None, 'CallOrdersPersianDateTime': '', 'CallOrderTimeVisibility': 'Collapsed', 'CallFirstTradedPrice': None, 'CallFirstTradedPriceTime': '', 'CallFirstTradedPriceChanges': None, 'CallFirstTradedPriceChangesPercent': None, 'CallFirstTradedPriceChangesVisibility': 'Collapsed', 'CallFirstTradedPriceChangesColor': 'Gray', 'CallLastTradedPrice': None, 'CallLastTradedPriceTime': '', 'CallLastTradedPriceChanges': None, 'CallLastTradedPriceChangesPercent': None, 'CallLastTradedPriceChangesVisibility': 'Collapsed', 'CallLastTradedPriceChangesColor': 'Gray', 'CallHighTradedPrice': None, 'CallHighTradedPriceChanges': None, 'CallHighTradedPriceChangesPercent': None, 'CallHighTradedPriceChangesVisibility': 'Collapsed', 'CallHighTradedPriceChangesColor': 'Gray', 'CallInitialMargin': 67400.0, 'CallRequiredMargin': 190704.0, 'CallLowTradedPrice': None, 'CallLowTradedPriceChanges': None, 'CallLowTradedPriceChangesPercent': None, 'CallLowTradedPriceChangesVisibility': 'Collapsed', 'CallLowTradedPriceChangesColor': 'Gray', 'CallTradesCount': 0, 'CallTradesVolume': None, 'CallTradesVolumeVisibility': 'Collapsed', 'CallTradesValue': None, 'CallTradesValueCurrencyFaDesc': '', 'CallTradesValueCurrencyEnDesc': '', 'CallOpenInterests': 16705653, 'CallOpenInterestsChanges': -3, 'CallOpenInterestsChangesPercent': 0.0, 'CallOpenInterestsChangesVisibility': 'Collapsed', 'CallOpenInterestsChangesColor': 'Gray', 'CallIsOrdersHighLight': False, 'CallIsTradesHighLight': False, 'CallOrdersCounter': -1, 'CallTradesCounter': -1, 'PutContractID': 1001971, 'PutContractCode': 'DGME05P23', 'PutContractDescription': 'قرارداد اختیار معامله فروش واحدهای سرمایه گذاری صندوق طلای درخشان آبان سررسید مهر ماه 1405 با قیمت اعمال 23،000 ریال', 'PutLastTradingPersianDate': '1405/07/18', 'PutContractSize': 10.0, 'PutContractSizeUnitFaDesc': 'واحد', 'PutContractCurrencyFaDesc': 'ریال', 'PutContractCurrencyEnDesc': 'Rials', 'PutLastSettlementPrice': 100.0, 'PutLastSettlementPricePersianDate': '1405/05/20', 'PutBidTotalVolume': None, 'PutBidVolume1': None, 'PutBidPrice1': None, 'PutBidVolume2': None, 'PutBidPrice2': None, 'PutBidVolume3': None, 'PutBidPrice3': None, 'PutBidVolume4': 0, 'PutBidPrice4': 0.0, 'PutBidVolume5': 0, 'PutBidPrice5': 0.0, 'PutAskTotalVolume': None, 'PutAskVolume1': None, 'PutAskPrice1': None, 'PutAskVolume2': None, 'PutAskPrice2': None, 'PutAskVolume3': None, 'PutAskPrice3': None, 'PutAskVolume4': 0, 'PutAskPrice4': 0.0, 'PutAskVolume5': 0, 'PutAskPrice5': 0.0, 'PutOrdersDateTime': None, 'PutOrdersPersianDateTime': '', 'PutOrderTimeVisibility': 'Collapsed', 'PutFirstTradedPrice': None, 'PutFirstTradedPriceTime': '', 'PutFirstTradedPriceChanges': None, 'PutFirstTradedPriceChangesPercent': None, 'PutFirstTradedPriceChangesVisibility': 'Collapsed', 'PutFirstTradedPriceChangesColor': 'Gray', 'PutLastTradedPrice': None, 'PutLastTradedPriceTime': '', 'PutLastTradedPriceChanges': None, 'PutLastTradedPriceChangesPercent': None, 'PutLastTraded ...

# %%
import pandas as pd

display(pd.DataFrame(md.gavahi).head(5))
# display(pd.DataFrame(md.sandoq).head(5))
# display(pd.DataFrame(md.future).head(5))
# display(pd.DataFrame(md.cdc).head(5))
# display(pd.DataFrame(md.markets_info).head(5))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame(md.markets_info)

calls = pd.DataFrame({
    # اطلاعات پایه
    'ContractCode': df['CallContractCode'],
    'ContractID': df['CallContractID'],
    # نوع قرارداد
    'Type': 'Call',

    'Description': df['CallContractDescription'],
    'LastTradingDate': df['CallLastTradingPersianDate'],
    'StrikePrice': pd.to_numeric(df['StrikePrice'], errors='coerce').fillna(0.0),
    'ContractSize': pd.to_numeric(df['CallContractSize'], errors='coerce').fillna(1.0),
    'CurrencyFa': df['CallContractCurrencyFaDesc'],
    'LastSettlementPrice': pd.to_numeric(df['CallLastSettlementPrice'], errors='coerce').fillna(0.0),
    'LastSettlementDate': df['CallLastSettlementPricePersianDate'],
    
    # اطلاعات سفارشات (Bid)
    'BidTotalVolume': pd.to_numeric(df['CallBidTotalVolume'], errors='coerce').fillna(0.0),
    'BidVolume1': pd.to_numeric(df['CallBidVolume1'], errors='coerce').fillna(0.0),
    'BidPrice1': pd.to_numeric(df['CallBidPrice1'], errors='coerce').fillna(0.0),
    
    # اطلاعات سفارشات (Ask)
    'AskTotalVolume': pd.to_numeric(df['CallAskTotalVolume'], errors='coerce').fillna(0.0),
    'AskVolume1': pd.to_numeric(df['CallAskVolume1'], errors='coerce').fillna(0.0),
    'AskPrice1': pd.to_numeric(df['CallAskPrice1'], errors='coerce').fillna(0.0),
    
    # حاشیه و حجم معاملات
    'InitialMargin': pd.to_numeric(df['CallInitialMargin'], errors='coerce').fillna(0.0),
    'RequiredMargin': pd.to_numeric(df['CallRequiredMargin'], errors='coerce').fillna(0.0),
    'TradesCount': pd.to_numeric(df['CallTradesCount'], errors='coerce').fillna(0),
    'TradesVolume': pd.to_numeric(df['CallTradesVolume'], errors='coerce').fillna(0.0),
    'TradesValue': pd.to_numeric(df['CallTradesValue'], errors='coerce').fillna(0.0),
    
    # موقعیت‌های باز
    'OpenInterests': pd.to_numeric(df['CallOpenInterests'], errors='coerce').fillna(0.0),
    'OpenInterestsChanges': pd.to_numeric(df['CallOpenInterestsChanges'], errors='coerce').fillna(0.0),
    'OpenInterestsChangesPercent': pd.to_numeric(df['CallOpenInterestsChangesPercent'], errors='coerce').fillna(0.0),
    
    # اطلاعات مشترک
    'StrikeLevel': df['StrikeLevel'],
})

puts = pd.DataFrame({
    # اطلاعات پایه
    'ContractCode': df['PutContractCode'],
    'ContractID': df['PutContractID'],
    # نوع قرارداد
    'Type': 'Put',

    'Description': df['PutContractDescription'],
    'LastTradingDate': df['PutLastTradingPersianDate'],
    'StrikePrice': pd.to_numeric(df['StrikePrice'], errors='coerce').fillna(0.0),
    'ContractSize': pd.to_numeric(df['PutContractSize'], errors='coerce').fillna(1.0),
    'CurrencyFa': df['PutContractCurrencyFaDesc'],
    'LastSettlementPrice': pd.to_numeric(df['PutLastSettlementPrice'], errors='coerce').fillna(0.0),
    'LastSettlementDate': df['PutLastSettlementPricePersianDate'],
    
    # اطلاعات سفارشات (Bid)
    'BidTotalVolume': pd.to_numeric(df['PutBidTotalVolume'], errors='coerce').fillna(0.0),
    'BidVolume1': pd.to_numeric(df['PutBidVolume1'], errors='coerce').fillna(0.0),
    'BidPrice1': pd.to_numeric(df['PutBidPrice1'], errors='coerce').fillna(0.0),
    
    # اطلاعات سفارشات (Ask)
    'AskTotalVolume': pd.to_numeric(df['PutAskTotalVolume'], errors='coerce').fillna(0.0),
    'AskVolume1': pd.to_numeric(df['PutAskVolume1'], errors='coerce').fillna(0.0),
    'AskPrice1': pd.to_numeric(df['PutAskPrice1'], errors='coerce').fillna(0.0),
    
    # حاشیه و حجم معاملات
    'InitialMargin': pd.to_numeric(df['PutInitialMargin'], errors='coerce').fillna(0.0),
    'RequiredMargin': pd.to_numeric(df['PutRequiredMargin'], errors='coerce').fillna(0.0),
    'TradesCount': pd.to_numeric(df['PutTradesCount'], errors='coerce').fillna(0),
    'TradesVolume': pd.to_numeric(df['PutTradesVolume'], errors='coerce').fillna(0.0),
    'TradesValue': pd.to_numeric(df['PutTradesValue'], errors='coerce').fillna(0.0),
    
    # موقعیت‌های باز
    'OpenInterests': pd.to_numeric(df['PutOpenInterests'], errors='coerce').fillna(0.0),
    'OpenInterestsChanges': pd.to_numeric(df['PutOpenInterestsChanges'], errors='coerce').fillna(0.0),
    'OpenInterestsChangesPercent': pd.to_numeric(df['PutOpenInterestsChangesPercent'], errors='coerce').fillna(0.0),
    
    # اطلاعات مشترک
    'StrikeLevel': df['StrikeLevel'],
})

# ترکیب نهایی
result = pd.concat([calls, puts], ignore_index=True)

# سورت
result = result.sort_values(
    ['LastTradingDate', 'Type'], ascending=[True, True]).reset_index(drop=True)
result.to_excel('df_kala.xlsx', index=False)

# %%
sandoq = pd.DataFrame(md.sandoq)
print(sandoq)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# دریافت دیتا به روش کتابخانه

# %%
import requests
import pandas as pd
import time

url_1 = 'https://cdn.ime.co.ir/realTimeServer/negotiate'

_timestamp = str(time.time()).replace(".", "")[:13]

params_1 = {'clientProtocol': '2.1', 'connectionData': '[{"name":"marketshub"}]', '_': _timestamp}
response_1 = requests.request(method="get", url=url_1, params=params_1)
response_1.raise_for_status()
negotiate_response = response_1.json()
connection_token = negotiate_response.get("ConnectionToken")

params_2 = {'transport': 'longPolling', 'connectionToken': connection_token, '_': _timestamp}
url2 = 'https://cdn.ime.co.ir/realTimeServer/connect'
response_2 = requests.request(method="post", url=url2, params=params_2)
response_2.raise_for_status()
connect_response = response_2.json()
message_id = connect_response.get("C")

params_3 = {'clientProtocol': '2.1', 'connectionData': '[{"name":"marketshub"}]', 'transport': 'longPolling', 'connectionToken': connection_token, '_': _timestamp}
url3 = 'https://cdn.ime.co.ir/realTimeServer/start'
response_3 = requests.request(method="post", url=url3, params=params_3)
response_3.raise_for_status()
res3 = response_3.json()

params_4 = {'clientProtocol': '2.1', 'connectionData': '[{"name":"marketshub"}]', 'transport': 'longPolling', 'connectionToken': connection_token}
url4 = 'https://cdn.ime.co.ir/realTimeServer/poll'
response_4 = requests.request(method="post", url=url4, params=params_4, data=f'messageId={message_id}', timeout=20)
response_4.raise_for_status()
res4 = response_4.json()

messages = res4.get('M', [])
for record in messages:
    if record["M"] == 'updateMarketsInfo':
        a = record["A"][0]
df = pd.DataFrame(a)
df.to_excel('df_markets_info.xlsx', index=False)

# %% [markdown]
# دریافت دیتا به روش خودم و مستقیم

# %%
import requests
import pandas as pd
import re
import jdatetime

def extract_strike_from_description(description: str) -> float:
    """
    استخراج قیمت اعمال از توضیحات قرارداد
    مثال: '... با قیمت اعمال 22,000 ریال' -> 22000
    """
    if pd.isna(description):
        return 0.0
    
    desc = str(description)
    
    # الگوی قیمت اعمال: اعداد با کاما یا بدون کاما
    pattern = r'قیمت اعمال\s*([\d,،]+)'
    
    match = re.search(pattern, desc)
    if match:
        # حذف تمام کاماها (فارسی و انگلیسی)
        strike_str = match.group(1).replace(',', '').replace('،', '')
        try:
            return float(strike_str)
        except:
            return 0.0
    
    return 0.0


def extract_fund_name(description: str) -> str:
    """
    استخراج نام دارایی پایه از توضیحات قرارداد
    بر اساس ساختار: قرارداد اختیار معامله [خرید/فروش] [دارایی پایه] سررسید ...
    """
    if pd.isna(description):
        return ""
    desc = str(description)
    
    # حذف عبارت ابتدایی: "قرارداد اختیار معامله خرید" یا "قرارداد اختیار معامله فروش"
    # و همچنین حذف "واحدهای سرمایه گذاری" در صورت وجود"
    cleaned = re.sub(r'^قرارداد اختیار معامله (خرید|فروش)\s+', '', desc)
    cleaned = re.sub(r'واحدهای سرمایه گذاری\s+', '', cleaned)
    
    # استخراج تا کلمه "سررسید"
    match = re.search(r'^(.*?)\s+سررسید', cleaned)
    if match:
        return match.group(1).strip()
    
    return ""

def extract_option_type(contract_code: str) -> str:
    """
    تشخیص نوع اختیار از روی کد قرارداد
    """
    if pd.isna(contract_code):
        return 'Unknown'
    
    code = str(contract_code)
    
    if 'C' in code and 'P' not in code:
        return 'Call'
    elif 'P' in code:
        return 'Put'
    else:
        return 'Unknown'


def calculate_days_to_maturity(delivery_date: str, last_trade_date: str) -> int:
    """
    محاسبه تعداد روزهای مانده تا سررسید
    """
    if pd.isna(delivery_date) or pd.isna(last_trade_date):
        return 0
    
    try:
        # تبدیل تاریخ شمسی به میلادی
        delivery_parts = delivery_date.split('/')
        last_trade_parts = last_trade_date.split('/')
        
        delivery_gregorian = jdatetime.date(
            int(delivery_parts[0]), 
            int(delivery_parts[1]), 
            int(delivery_parts[2])).togregorian()
        
        last_trade_gregorian = jdatetime.date(
            int(last_trade_parts[0]), 
            int(last_trade_parts[1]), 
            int(last_trade_parts[2])).togregorian()
        
        # اختلاف به روز
        delta = delivery_gregorian - last_trade_gregorian
        return delta.days
        
    except:
        return 0


def summarize_contract(group, last_market_date):
    """
    خلاصه‌سازی داده‌های هر قرارداد
    """
    # مرتب‌سازی بر اساس تاریخ (جدیدترین آخر)
    group = group.sort_values('DT_en', ascending=False)
    
    # پیدا کردن ردیف مربوط به آخرین روز بازار
    latest_day_row = group[group['DT_en'] == last_market_date]

    if not latest_day_row.empty:
        # اگر در آخرین روز بازار معامله داشته، از آن استفاده کن
        latest = latest_day_row.iloc[0].copy()
    else:
        # اگر در آخرین روز بازار معامله نداشته،
        # از آخرین روزی که معامله داشته استفاده کن
        latest = group.iloc[0].copy()
        
        # اما تاریخ را به آخرین روز بازار تغییر بده
        # و حجم و ارزش را صفر کن (چون در آن روز معامله نداشته)
        latest['TradesVolume'] = 0
        latest['TradesValue'] = 0
        latest['DT_en'] = last_market_date


    # تبدیل آخرین روز به دیکشنری (همه ستون‌ها حفظ می‌شوند)
    summary = latest.to_dict()

    # محاسبه مجموع و میانگین
    total_volume = group['TradesVolume'].sum()
    days_count = len(group)
    
    # ستون‌های خلاصه
    # summary['TotalDaysCount'] = days_count               # تعداد روزها

    # میانگین روزانه
    summary['AvgTradesVolume'] = round(total_volume / days_count ,0) if days_count > 0 else 0
    
    return pd.Series(summary)


url = "https://www.ime.co.ir/subsystems/ime/option/optionboarddata.ashx"

params = {
    'f': '1405/05/15',
    't': '1406/5/22',
    'c': '-1',
    'ot': '0',
    'lang': '8',
    'order': 'asc',
    'offset': '0',}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:153.0) Gecko/20100101 Firefox/153.0',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Pragma': 'no-cache',}

# درخواست GET با استفاده از Session برای حفظ کوکی‌ها
session = requests.Session()
response = session.get(url, params=params, headers=headers)

# بررسی وضعیت درخواست
response.raise_for_status()

# تبدیل به JSON
response_data = response.json()

rows = response_data.get('rows', [])
df_rows = pd.DataFrame(rows)

df_rows['StrikePrice'] = df_rows['ContractDescription'].apply(extract_strike_from_description)
df_rows['AssetName'] = df_rows['ContractDescription'].apply(extract_fund_name)
df_rows['OptionType'] = df_rows['ContractCode'].apply(extract_option_type)
# افزودن ستون DaysToMaturity
df_rows['DaysToMaturity'] = df_rows.apply(
    lambda row: calculate_days_to_maturity(row['DeliveryDate'], row['DT']), axis=1)
df_rows['DT_en'] = pd.to_datetime(df_rows['DT_en'], errors='coerce')

# ============= محاسبه آخرین روز معاملاتی کل بازار =============
last_market_date = df_rows['DT_en'].max()

df_rows = df_rows.groupby('ContractCode', group_keys=False).apply(
    lambda g: summarize_contract(g, last_market_date), include_groups=False).reset_index(drop=True)

df_rows = df_rows[df_rows['AvgTradesVolume'] > 0]
# سورت
df_rows = df_rows.sort_values(
    ['AssetName', 'OptionType', 'StrikePrice'],
    ascending=[True, True, True]).reset_index(drop=True)

df_rows.to_excel('df_rows.xlsx', index=False)

unique_assets = df_rows['AssetName'].unique()
print(len(unique_assets))
print(unique_assets)
# Out:
# 7
# ['شمش طلا' 'شمش نقره' 'صندوق طلای درخشان آبان' 'صندوق طلای دنای زاگرس'
#  'صندوق طلای پارسیان' 'صندوق طلای کارآمد' 'صندوق طلای کهربا']

# %%
import requests
import pandas as pd


url = 'https://old.tsetmc.com/tsev2/data/MarketWatchInit.aspx?h=0&r=0'
darkhast = requests.get(url, timeout=30)
nemad = darkhast.text.split(';')[1:]

main_text = darkhast.text
text = main_text.split(';')
csvs = main_text.split('@')
main_csv = csvs[2]
csv = main_csv.split(';')
rows = [row.split(',') for row in csv]

columns = ['ID', 'ISO', 'nemad', 'name', '4', 'open', 'payani',
           'last', "NumberOfTrades", 'Volume', 'arzesh_trade',
           'baze_min_rooz', 'baze_max_rooz', 'Yesterday_Price',
           'EPS', 'Base_Volume', '16', '17', '18', 'geymat_mojaz_max',
           'geymat_mojaz_min', 'Number_saham', 'group_code', 'extra1', 'extra2', 'extra3']

df_rows_bourse = pd.DataFrame(rows, columns=columns)
df_rows_bourse = df_rows_bourse[df_rows_bourse['group_code'] == '380'].reset_index(drop=True)
df_rows_bourse.to_excel('df_tse.xlsx', index=False)
df_rows_bourse

# %%
# ایجاد دیکشنری برای نگاشت نام صندوق‌ها به قیمت آخرین معامله از بورس
df_rows_bourse_filtered = df_rows_bourse[df_rows_bourse['extra3'] == 'QS'].copy()
fund_prices = df_rows_bourse_filtered.set_index('name')['last'].to_dict()

# نگاشت نام‌های صندوق‌ها در بورس کالا به نمادهای بورس
fund_mapping = {
    'صندوق طلای کهربا' : 'صندوق س. كالاي كهربا',
    'صندوق طلای درخشان آبان' : 'صندوق س.كالاي آبان',
    'صندوق طلای دنای زاگرس': 'صندوق س.كالاي دناي زاگرس',
    'صندوق طلای کارآمد' : 'صندوق س.كالاي كارآمد',
    'صندوق طلای پارسیان' : 'صندوق س. كالاي پارسيان',
    'شمش طلا': None,  # برای شمش طلا قیمت جداگانه محاسبه می‌شود
    'شمش نقره': None,  # برای شمش نقره قیمت جداگانه محاسبه می‌شود
}

# تزریق قیمت پایه به دیتافریم بورس کالا
def get_underlying_price(asset_name):
    if asset_name in fund_mapping:
        symbol = fund_mapping[asset_name]
        if symbol and symbol in fund_prices:
            return float(fund_prices[symbol])
    return 0.0

df_rows['UnderlyingPrice'] = df_rows['AssetName'].apply(get_underlying_price)
df_rows.to_excel('df_kala.xlsx', index=False)
